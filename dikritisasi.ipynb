# %% [markdown]
# Mendiscretisasi (diskritisasi)
#
# Diskritisasi adalah proses mengubah nilai numerik menjadi kategori (misalnya dari angka ke “rendah”, “sedang”, “tinggi”).
#
# Load dan Persiapkan Data

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['Class'] = [iris.target_names[i] for i in iris.target]
df.insert(0, 'id', range(1, len(df)+1))
df = df[['id', 'Class', 'petal length (cm)', 'petal width (cm)', 'sepal length (cm)', 'sepal width (cm)']]
df.columns = ['id', 'Class', 'petal_length', 'petal_width', 'sepal_length', 'sepal_width']

print(df.to_string(index=False))
# Out:
#  id      Class  petal_length  petal_width  sepal_length  sepal_width
#   1     setosa           1.4          0.2           5.1          3.5
#   2     setosa           1.4          0.2           4.9          3.0
#   3     setosa           1.3          0.2           4.7          3.2
#   4     setosa           1.5          0.2           4.6          3.1
#   5     setosa           1.4          0.2           5.0          3.6
#   6     setosa           1.7          0.4           5.4          3.9
#   7     setosa           1.4          0.3           4.6          3.4
#   8     setosa           1.5          0.2           5.0          3.4
#   9     setosa           1.4          0.2           4.4          2.9
#  10     setosa           1.5          0.1           4.9          3.1
#  11     setosa           1.5          0.2           5.4          3.7
#  12     setosa           1.6          0.2           4.8          3.4
#  13     setosa           1.4          0.1           4.8          3.0
#  14     setosa           1.1          0.1           4.3          3.0
#  15     setosa           1.2          0.2           5.8          4.0
#  16     setosa           1.5          0.4           5.7          4.4
#  17     setosa           1.3          0.4           5.4          3.9
#  18     setosa           1.4          0.3           5.1          3.5
#  19     setosa           1.7          0.3           5.7          3.8
#  20     setosa           1.5          0.3           5.1          3.8
#  21     setosa           1.7          0.2           5.4          3.4
#  22     setosa           1.5          0.4           5.1          3.7
#  23     setosa           1.0          0.2           4.6          3.6
#  24     setosa           1.7          0.5           5.1          3.3
#  25     setosa           1.9          0.2           4.8          3.4
#  26     setosa           1.6          0.2           5.0          3.0
#  27     setosa           1.6          0.4           5.0          3.4
#  28     setosa           1.5          0.2           5.2          3.5
#  29     setosa           1.4          0.2           5.2          3.4
#  30     setosa           1.6          0.2           4.7          3.2
#  31     setosa           1.6          0.2           4.8          3.1
#  32     setosa           1.5          0.4           5.4          3.4
#  33     setosa           1.5          0.1           5.2          4.1
#  34     setosa           1.4          0.2           5.5          4.2
#  35     setosa           1.5          0.2           4.9          3.1
#  36     setosa           1.2          0.2           5.0          3.2
#  37     setosa           1.3          0.2           5.5          3.5
#  38     setosa           1.4          0.1           4.9          3.6
#  39     setosa           1.3          0.2           4.4          3.0
#  40     setosa           1.5          0.2           5.1          3.4
#  41     setosa           1.3          0.3           5.0          3.5
#  42     setosa           1.3          0.3           4.5          2.3
#  43     setosa           1.3          0.2           4.4          3.2
#  44     setosa           1.6          0.6           5.0          3.5
#  45     setosa           1.9          0.4           5.1          3.8
#  46     setosa           1.4          0.3           4.8          3.0
#  47     setosa           1.6          0.2           5.1          3.8
#  48     setosa           1.4          0.2           4.6          3.2
#  49     setosa           1.5          0.2           5.3          3.7
#  50     setosa           1.4          0.2           5.0          3.3
#  51 versicolor           4.7          1.4           7.0          3.2
#  52 versicolor           4.5          1.5           6.4          3.2
#  53 versicolor           4.9          1.5           6.9          3.1
#  54 versicolor           4.0          1.3           5.5          2.3
#  55 versicolor           4.6          1.5           6.5          2.8
#  56 versicolor           4.5          1.3           5.7          2.8
#  57 versicolor           4.7          1.6           6.3          3.3
#  58 versicolor           3.3          1.0           4.9          2.4
#  59 versicolor           4.6          1.3           6.6          2.9
#  60 versicolor           3.9          1.4           5.2          2.7
#  61 versicolor           3.5          1.0           5.0          2.0
#  62 versicolor           4.2          1.5           5.9          3.0
#  63 versicolor           4.0          1.0           6.0          2.2
#  64 versicolor           4.7          1.4           6.1          2.9
#  65 versicolor           3.6          1.3           5.6          2.9
#  66 versicolor           4.4          1.4           6.7          3.1
#  67 versicolor           4.5          1.5           5.6          3.0
#  68 versicolor           4.1          1.0           5.8          2.7
#  69 versicolor           4.5          1.5           6.2          2.2
#  70 versicolor           3.9          1.1           5.6          2.5
#  71 versicolor           4.8          1.8           5.9          3.2
#  72 versicolor           4.0          1.3           6.1          2.8
#  73 versicolor           4.9          1.5           6.3          2.5
#  74 versicolor           4.7          1.2           6.1          2.8
#  75 versicolor           4.3          1.3           6.4          2.9
#  76 versicolor           4.4          1.4           6.6          3.0
#  77 versicolor           4.8          1.4           6.8          2.8
#  78 versicolor           5.0          1.7           6.7          3.0
#  79 versicolor           4.5          1.5           6.0          2.9
#  80 versicolor           3.5          1.0           5.7          2.6
#  81 versicolor           3.8          1.1           5.5          2.4
#  82 versicolor           3.7          1.0           5.5          2.4
#  83 versicolor           3.9          1.2           5.8          2.7
#  84 versicolor           5.1          1.6           6.0          2.7
#  85 versicolor           4.5          1.5           5.4          3.0
#  86 versicolor           4.5          1.6           6.0          3.4
#  87 versicolor           4.7          1.5           6.7          3.1
#  88 versicolor           4.4          1.3           6.3          2.3
#  89 versicolor           4.1          1.3           5.6          3.0
#  90 versicolor           4.0          1.3           5.5          2.5
#  91 versicolor           4.4          1.2           5.5          2.6
#  92 versicolor           4.6          1.4           6.1          3.0
#  93 versicolor           4.0          1.2           5.8          2.6
#  94 versicolor           3.3          1.0           5.0          2.3
#  95 versicolor           4.2          1.3           5.6          2.7
#  96 versicolor           4.2          1.2           5.7          3.0
#  97 versicolor           4.2          1.3           5.7          2.9
#  98 versicolor           4.3          1.3           6.2          2.9
#  99 versicolor           3.0          1.1           5.1          2.5
# 100 versicolor           4.1          1.3           5.7          2.8
# 101  virginica           6.0          2.5           6.3          3.3
# 102  virginica           5.1          1.9           5.8          2.7
# 103  virginica           5.9          2.1           7.1          3.0
# 104  virginica           5.6          1.8           6.3          2.9
# 105  virginica           5.8          2.2           6.5          3.0
# 106  virginica           6.6          2.1           7.6          3.0
# 107  virginica           4.5          1.7           4.9          2.5
# 108  virginica           6.3          1.8           7.3          2.9
# 109  virginica           5.8          1.8           6.7          2.5
# 110  virginica           6.1          2.5           7.2          3.6
# 111  virginica           5.1          2.0           6.5          3.2
# 112  virginica           5.3          1.9           6.4          2.7
# 113  virginica           5.5          2.1           6.8          3.0
# 114  virginica           5.0          2.0           5.7          2.5
# 115  virginica           5.1          2.4           5.8          2.8
# 116  virginica           5.3          2.3           6.4          3.2
# 117  virginica           5.5          1.8           6.5          3.0
# 118  virginica           6.7          2.2           7.7          3.8
# 119  virginica           6.9          2.3           7.7          2.6
# 120  virginica           5.0          1.5           6.0          2.2
# 121  virginica           5.7          2.3           6.9          3.2
# 122  virginica           4.9          2.0           5.6          2.8
# 123  virginica           6.7          2.0           7.7          2.8
# 124  virginica           4.9          1.8           6.3          2.7
# 125  virginica           5.7          2.1           6.7          3.3
# 126  virginica           6.0          1.8           7.2          3.2
# 127  virginica           4.8          1.8           6.2          2.8
# 128  virginica           4.9          1.8           6.1          3.0
# 129  virginica           5.6          2.1           6.4          2.8
# 130  virginica           5.8          1.6           7.2          3.0
# 131  virginica           6.1          1.9           7.4          2.8
# 132  virginica           6.4          2.0           7.9          3.8
# 133  virginica           5.6          2.2           6.4          2.8
# 134  virginica           5.1          1.5           6.3          2.8
# 135  virginica           5.6          1.4           6.1          2.6
# 136  virginica           6.1          2.3           7.7          3.0
# 137  virginica           5.6          2.4           6.3          3.4
# 138  virginica           5.5          1.8           6.4          3.1
# 139  virginica           4.8          1.8           6.0          3.0
# 140  virginica           5.4          2.1           6.9          3.1
# 141  virginica           5.6          2.4           6.7          3.1
# 142  virginica           5.1          2.3           6.9          3.1
# 143  virginica           5.1          1.9           5.8          2.7
# 144  virginica           5.9          2.3           6.8          3.2
# 145  virginica           5.7          2.5           6.7          3.3
# 146  virginica           5.2          2.3           6.7          3.0
# 147  virginica           5.0          1.9           6.3          2.5
# 148  virginica           5.2          2.0           6.5          3.0
# 149  virginica           5.4          2.3           6.2          3.4
# 150  virginica           5.1          1.8           5.9          3.0

# %% [markdown]
# Diskritisasi Semua Fitur dengan KMeans

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

# Load data Iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Tambahkan kolom Class dan ID
df['Class'] = [iris.target_names[i] for i in iris.target]
df.insert(0, 'id', range(1, len(df) + 1))

# Ubah urutan dan nama kolom agar lebih singkat
df = df[['id', 'Class', 'petal length (cm)', 'petal width (cm)', 'sepal length (cm)', 'sepal width (cm)']]
df.columns = ['id', 'Class', 'petal_length', 'petal_width', 'sepal_length', 'sepal_width']

# Salin DataFrame untuk diskritisasi
df_discrete = df.copy()

# Mapping angka ke huruf kategori
label_map = {0: 'A', 1: 'B', 2: 'C'}

# Diskritisasi tiap fitur numerik menggunakan KMeans dan ubah ke huruf
for col in ['petal_length', 'petal_width', 'sepal_length', 'sepal_width']:
    kmeans = KMeans(n_clusters=3, random_state=42)
    clusters = kmeans.fit_predict(df[[col]])
    
    # Urutkan berdasarkan rata-rata nilai asli per cluster
    centers = pd.DataFrame({'cluster': clusters, 'value': df[col]})
    ordered = centers.groupby('cluster').mean().sort_values('value').index
    cluster_to_label = {cluster: label_map[i] for i, cluster in enumerate(ordered)}
    
    df_discrete[col] = [cluster_to_label[c] for c in clusters]

# Tampilkan hasil akhir
print(df_discrete.to_string(index=False))
# Out:
#  id      Class petal_length petal_width sepal_length sepal_width
#   1     setosa            A           A            A           C
#   2     setosa            A           A            A           B
#   3     setosa            A           A            A           B
#   4     setosa            A           A            A           B
#   5     setosa            A           A            A           C
#   6     setosa            A           A            B           C
#   7     setosa            A           A            A           C
#   8     setosa            A           A            A           C
#   9     setosa            A           A            A           B
#  10     setosa            A           A            A           B
#  11     setosa            A           A            B           C
#  12     setosa            A           A            A           C
#  13     setosa            A           A            A           B
#  14     setosa            A           A            A           B
#  15     setosa            A           A            B           C
#  16     setosa            A           A            B           C
#  17     setosa            A           A            B           C
#  18     setosa            A           A            A           C
#  19     setosa            A           A            B           C
#  20     setosa            A           A            A           C
#  21     setosa            A           A            B           C
#  22     setosa            A           A            A           C
#  23     setosa            A           A            A           C
#  24     setosa            A           A            A           C
#  25     setosa            A           A            A           C
#  26     setosa            A           A            A           B
#  27     setosa            A           A            A           C
#  28     setosa            A           A            A           C
#  29     setosa            A           A            A           C
#  30     setosa            A           A            A           B
#  31     setosa            A           A            A           B
#  32     setosa            A           A            B           C
#  33     setosa            A           A            A           C
#  34     setosa            A           A            B           C
#  35     setosa            A           A            A           B
#  36     setosa            A           A            A           B
#  37     setosa            A           A            B           C
#  38     setosa            A           A            A           C
#  39     setosa            A           A            A           B
#  40     setosa            A           A            A           C
#  41     setosa            A           A            A           C
#  42     setosa            A           A            A           A
#  43     setosa            A           A            A           B
#  44     setosa            A           A            A           C
#  45     setosa            A           A            A           C
#  46     setosa            A           A            A           B
#  47     setosa            A           A            A           C
#  48     setosa            A           A            A           B
#  49     setosa            A           A            A           C
#  50     setosa            A           A            A           C
#  51 versicolor            B           B            C           B
#  52 versicolor            B           B            C           B
#  53 versicolor            C           B            C           B
#  54 versicolor            B           B            B           A
#  55 versicolor            B           B            C           B
#  56 versicolor            B           B            B           B
#  57 versicolor            B           B            C           C
#  58 versicolor            B           B            A           A
#  59 versicolor            B           B            C           B
#  60 versicolor            B           B            A           A
#  61 versicolor            B           B            A           A
#  62 versicolor            B           B            B           B
#  63 versicolor            B           B            B           A
#  64 versicolor            B           B            B           B
#  65 versicolor            B           B            B           B
#  66 versicolor            B           B            C           B
#  67 versicolor            B           B            B           B
#  68 versicolor            B           B            B           A
#  69 versicolor            B           B            B           A
#  70 versicolor            B           B            B           A
#  71 versicolor            B           C            B           B
#  72 versicolor            B           B            B           B
#  73 versicolor            C           B            C           A
#  74 versicolor            B           B            B           B
#  75 versicolor            B           B            C           B
#  76 versicolor            B           B            C           B
#  77 versicolor            B           B            C           B
#  78 versicolor            C           C            C           B
#  79 versicolor            B           B            B           B
#  80 versicolor            B           B            B           A
#  81 versicolor            B           B            B           A
#  82 versicolor            B           B            B           A
#  83 versicolor            B           B            B           A
#  84 versicolor            C           B            B           A
#  85 versicolor            B           B            B           B
#  86 versicolor            B           B            B           C
#  87 versicolor            B           B            C           B
#  88 versicolor            B           B            C           A
#  89 versicolor            B           B            B           B
#  90 versicolor            B           B            B           A
#  91 versicolor            B           B            B           A
#  92 versicolor            B           B            B           B
#  93 versicolor            B           B            B           A
#  94 versicolor            B           B            A           A
#  95 versicolor            B           B            B           A
#  96 versicolor            B           B            B           B
#  97 versicolor            B           B            B           B
#  98 versicolor            B           B            B           B
#  99 versicolor            B           B            A           A
# 100 versicolor            B           B            B           B
# 101  virginica            C           C            C           C
# 102  virginica            C           C            B           A
# 103  virginica            C           C            C           B
# 104  virginica            C           C            C           B
# 105  virginica            C           C            C           B
# 106  virginica            C           C            C           B
# 107  virginica            B           C            A           A
# 108  virginica            C           C            C           B
# 109  virginica            C           C            C           A
# 110  virginica            C           C            C           C
# 111  virginica            C           C            C           B
# 112  virginica            C           C            C           A
# 113  virginica            C           C            C           B
# 114  virginica            C           C            B           A
# 115  virginica            C           C            B           B
# 116  virginica            C           C            C           B
# 117  virginica            C           C            C           B
# 118  virginica            C           C            C           C
# 119  virginica            C           C            C           A
# 120  virginica            C           B            B           A
# 121  virginica            C           C            C           B
# 122  virginica            C           C            B           B
# 123  virginica            C           C            C           B
# 124  virginica            C           C            C           A
# 125  virginica            C           C            C           C
# 126  virginica            C           C            C           B
# 127  virginica            B           C            B           B
# 128  virginica            C           C            B           B
# 129  virginica            C           C            C           B
# 130  virginica            C           B            C           B
# 131  virginica            C           C            C           B
# 132  virginica            C           C            C           C
# 133  virginica            C           C            C           B
# 134  virginica            C           B            C           B
# 135  virginica            C           B            B           A
# 136  virginica            C           C            C           B
# 137  virginica            C           C            C           C
# 138  virginica            C           C            C           B
# 139  virginica            B           C            B           B
# 140  virginica            C           C            C           B
# 141  virginica            C           C            C           B
# 142  virginica            C           C            C           B
# 143  virginica            C           C            B           A
# 144  virginica            C           C            C           B
# 145  virginica            C           C            C           C
# 146  virginica            C           C            C           B
# 147  virginica            C           C            C           A
# 148  virginica            C           C            C           B
# 149  virginica            C           C            B           C
# 150  virginica            C           C            B           B

# %% [markdown]
# Klasifikasi Sebelum Diskritisasi

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['Class'] = [iris.target_names[i] for i in iris.target]
df.insert(0, 'id', range(1, len(df) + 1))
df = df[['id', 'Class', 'petal length (cm)', 'petal width (cm)', 'sepal length (cm)', 'sepal width (cm)']]
df.columns = ['id', 'Class', 'petal_length', 'petal_width', 'sepal_length', 'sepal_width']

# Klasifikasi SEBELUM diskritisasi
X = df.drop(columns=['id', 'Class'])
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

nb = GaussianNB()
nb.fit(X_train, y_train)
pred_nb = nb.predict(X_test)

dt = DecisionTreeClassifier(random_state=1)
dt.fit(X_train, y_train)
pred_dt = dt.predict(X_test)

# Output akurasi
print("=== Sebelum Diskritisasi (data asli) ===")
print("Naive Bayes Accuracy     :", accuracy_score(y_test, pred_nb))
print("Decision Tree Accuracy   :", accuracy_score(y_test, pred_dt))
# Out:
# === Sebelum Diskritisasi (data asli) ===
# Naive Bayes Accuracy     : 0.9666666666666667
# Decision Tree Accuracy   : 0.9666666666666667

# %% [markdown]
# Klasifikasi Setelah Diskritisasi

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

# Copy data asli untuk diskritisasi
df_discrete = df.copy()
label_map = {0: 'A', 1: 'B', 2: 'C'}

# Diskritisasi semua fitur
for col in ['petal_length', 'petal_width', 'sepal_length', 'sepal_width']:
    kmeans = KMeans(n_clusters=3, random_state=42)
    clusters = kmeans.fit_predict(df[[col]])
    
    # Urutkan cluster agar A = nilai rendah, B = sedang, C = tinggi
    centers = pd.DataFrame({'cluster': clusters, 'value': df[col]})
    ordered = centers.groupby('cluster').mean().sort_values('value').index
    cluster_to_label = {cluster: label_map[i] for i, cluster in enumerate(ordered)}
    
    df_discrete[col] = [cluster_to_label[c] for c in clusters]

# Ubah kategori A/B/C menjadi angka 0/1/2
df_encoded = df_discrete.copy()
for col in ['petal_length', 'petal_width', 'sepal_length', 'sepal_width']:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col])

# Klasifikasi SETELAH diskritisasi
X_d = df_encoded.drop(columns=['id', 'Class'])
y_d = df_encoded['Class']

X_train_d, X_test_d, y_train_d, y_test_d = train_test_split(X_d, y_d, test_size=0.2, random_state=1)

nb_d = GaussianNB()
nb_d.fit(X_train_d, y_train_d)
pred_nb_d = nb_d.predict(X_test_d)

dt_d = DecisionTreeClassifier(random_state=1)
dt_d.fit(X_train_d, y_train_d)
pred_dt_d = dt_d.predict(X_test_d)

# Output akurasi
print("\n=== Setelah Diskritisasi (A/B/C) ===")
print("Naive Bayes Accuracy     :", accuracy_score(y_test_d, pred_nb_d))
print("Decision Tree Accuracy   :", accuracy_score(y_test_d, pred_dt_d))
# Out:
# === Setelah Diskritisasi (A/B/C) ===
# Naive Bayes Accuracy     : 0.9666666666666667
# Decision Tree Accuracy   : 0.9666666666666667
